# %% [markdown]
# # Part 2 : Data Science

# %% [markdown]
#  Upload the HISP dataset and build-up a Pandas Dataframe containing the label (health_expenditures) and the up-mentioned features. Show and comment some descriptive statistics related to this Dataframe.

# %%
import pandas as pd
df = pd.read_csv ('/Users/emmabourdit/Desktop/Dauphine_M2_IREN/Data science/Rendu/Projet Final/HISP.csv')

# %%
df_Before = df.loc[df['round'] == 'Before']
df_Before = pd.DataFrame(df_Before, columns = ['health_expenditures','poverty_index', 'age_hh', 'age_sp', 'educ_hh', 'educ_sp', 'female_hh', 'indigenous', 'hhsize','dirtfloor', 'bathroom', 'land', 'hospital_distance', 'park', 'sports'])
df_Before
# Out:
#        health_expenditures  poverty_index  age_hh  age_sp  educ_hh  educ_sp  \
# 0                15.185455      55.950542    24.0      23      0.0      6.0
# 2                13.076257      46.058731    30.0      26      4.0      0.0
# 5                15.286353      54.095825    58.0      56      0.0      0.0
# 7                11.311761      56.903400    35.0      24      3.0      0.0
# 8                11.223912      46.908810    37.0      35      0.0      0.0
# ...                    ...            ...     ...     ...      ...      ...
# 19818            14.214518      74.980682    46.0      38      5.0      3.0
# 19820            13.606447      58.153015    38.0      41      3.0      2.0
# 19822            16.811539      59.737247    52.0      41      0.0      2.0
# 19823            15.906003      62.055641    51.0      40      5.0      2.0
# 19825             8.737772      62.828438    58.0      49      3.0      0.0
#
# ...

# %% [markdown]
# Show and comment some descriptive statistics related to this Dataframe.

# %%
df_Before[['health_expenditures','poverty_index', 'age_hh', 'age_sp', 'educ_hh', 'educ_sp', 'female_hh', 'indigenous', 'hhsize','dirtfloor', 'bathroom', 'land', 'hospital_distance', 'park', 'sports']].describe(include='all')
# Out:
#        health_expenditures  poverty_index       age_hh       age_sp  \
# count          9913.000000    9913.000000  9913.000000  9913.000000
# mean             17.210985      56.790404    46.200353    40.183900
# std               5.588098      10.685997    15.285329    12.794188
# min               6.252154      20.479134    14.000000    14.000000
# 25%              13.021940      49.652241    34.000000    30.000000
# 50%              16.839489      56.414219    45.000000    41.000000
# 75%              21.053459      62.905720    57.000000    47.000000
# max              35.626358     100.000000    88.000000    87.000000
#
#            educ_hh      educ_sp    female_hh   indigenous       hhsize  \
# count  9913.000000  9913.000000  9913.000000  9913.000000  9913.000000
# mean      2.833289     2.617573     0.099062     0.352870     5.178553
# std       2.754699     2.543095     0.298760     0.477887     2.195223
# ...

# %% [markdown]
# # First model

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import linear_model as lm

# %%
x = df_Before[['poverty_index', 'age_hh', 'age_sp', 'educ_hh', 'educ_sp', 'female_hh', 'indigenous', 'hhsize','dirtfloor', 'bathroom', 'land', 'hospital_distance', 'park', 'sports']]
y = df_Before[['health_expenditures']]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2) #to split the dataset

# %%
model = lm.LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pd.DataFrame(model.coef_[0], x.columns, columns = ['Coeff'])
# Out:
#                       Coeff
# poverty_index      0.051677
# age_hh             0.068312
# age_sp             0.012423
# educ_hh            0.157066
# educ_sp           -0.048563
# female_hh          1.638589
# indigenous        -2.727109
# hhsize            -2.002051
# dirtfloor         -2.559948
# bathroom           0.379575
# land               0.192607
# hospital_distance  0.000419
# park              -0.015035
# sports             0.000807

# %%
print(model.intercept_)
# Out:
# [22.37253711]

# %%
from sklearn import metrics

# %%
predictions = model.predict(x_test)

# %%
metrics.mean_squared_error(y_test, predictions)
# Out:
# 1.0744508744419625
